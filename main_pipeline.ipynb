# %%
# !pip install opencv-python matplotlib numpy pandas scikit-learn
# Out:
# Requirement already satisfied: opencv-python in c:\users\public\anaconda3\envs\fruit_monitor\lib\site-packages (4.10.0)
# Requirement already satisfied: matplotlib in c:\users\public\anaconda3\envs\fruit_monitor\lib\site-packages (3.10.0)
# Requirement already satisfied: numpy in c:\users\public\anaconda3\envs\fruit_monitor\lib\site-packages (2.1.3)
# Requirement already satisfied: pandas in c:\users\public\anaconda3\envs\fruit_monitor\lib\site-packages (2.2.3)
# Requirement already satisfied: scikit-learn in c:\users\public\anaconda3\envs\fruit_monitor\lib\site-packages (1.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\public\anaconda3\envs\fruit_monitor\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\public\anaconda3\envs\fruit_monitor\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\public\anaconda3\envs\fruit_monitor\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\public\anaconda3\envs\fruit_monitor\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\public\anaconda3\envs\fruit_monitor\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\public\anaconda3\envs\fruit_monitor\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\public\anaconda3\envs\fruit_monitor\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\public\anaconda3\envs\fruit_monitor\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\public\anaconda3\envs\fruit_monitor\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\public\anaconda3\envs\fruit_monitor\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\public\anaconda3\envs\fruit_monitor\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\public\anaconda3\envs\fruit_monitor\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\public\anaconda3\envs\fruit_monitor\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\public\anaconda3\envs\fruit_monitor\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import cv2
import matplotlib.pyplot as plt
import urllib.request
import numpy as np

# Download image from the internet
url = 'https://upload.wikimedia.org/wikipedia/commons/1/15/Red_Apple.jpg'
resp = urllib.request.urlopen(url)
image = np.asarray(bytearray(resp.read()), dtype="uint8")
img = cv2.imdecode(image, cv2.IMREAD_COLOR)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Display the image
plt.imshow(img)
plt.title("Sample Apple Image")
plt.axis('off')
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google.colab'
